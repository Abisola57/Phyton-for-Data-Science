# %% [markdown]
# Reg No: 057

# %%
#Import liberies
import pandas  as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
sns.set_style('darkgrid')
import warnings
warnings.filterwarnings('ignore')

# %%
data= pd.read_csv('https://raw.githubusercontent.com/Tiamiyu1/Python-for-Data-Science-and-Analytics/main/Data/supermarket_data.csv')

# %%
data.head(10)
# Out:
#     Invoice ID Branch       City Customer type  Gender  \
# 0  750-67-8428      A     Yangon        Member  Female
# 1  226-31-3081      C  Naypyitaw        Normal  Female
# 2  631-41-3108      A     Yangon        Normal    Male
# 3  123-19-1176      A     Yangon        Member    Male
# 4  373-73-7910      A     Yangon        Normal    Male
# 5  699-14-3026      C  Naypyitaw        Normal    Male
# 6  355-53-5943      A     Yangon        Member  Female
# 7  315-22-5665      C  Naypyitaw        Normal  Female
# 8  665-32-9167      A     Yangon        Member  Female
# 9  692-92-5582      B   Mandalay        Member  Female
#
#              Product line  Unit price  Quantity   Tax 5%     Total       Date  \
# 0       Health and beauty       74.69         7  26.1415  548.9715   1/5/2019
# 1  Electronic accessories       15.28         5   3.8200   80.2200   3/8/2019
# 2      Home and lifestyle       46.33         7  16.2155  340.5255   3/3/2019
# ...

# %%
data.describe().T
# Out:
#                           count        mean           std        min  \
# Unit price               1000.0   55.672130  2.649463e+01  10.080000
# Quantity                 1000.0    5.510000  2.923431e+00   1.000000
# Tax 5%                   1000.0   15.379369  1.170883e+01   0.508500
# Total                    1000.0  322.966749  2.458853e+02  10.678500
# cogs                     1000.0  307.587380  2.341765e+02  10.170000
# gross margin percentage  1000.0    4.761905  6.131498e-14   4.761905
# gross income             1000.0   15.379369  1.170883e+01   0.508500
# Rating                   1000.0    6.972700  1.718580e+00   4.000000
#
#                                 25%         50%         75%          max
# Unit price                32.875000   55.230000   77.935000    99.960000
# Quantity                   3.000000    5.000000    8.000000    10.000000
# Tax 5%                     5.924875   12.088000   22.445250    49.650000
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 17 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Invoice ID               1000 non-null   object
#  1   Branch                   1000 non-null   object
#  2   City                     1000 non-null   object
#  3   Customer type            1000 non-null   object
#  4   Gender                   1000 non-null   object
#  5   Product line             1000 non-null   object
#  6   Unit price               1000 non-null   float64
#  7   Quantity                 1000 non-null   int64
#  8   Tax 5%                   1000 non-null   float64
#  9   Total                    1000 non-null   float64
#  10  Date                     1000 non-null   object
#  11  Time                     1000 non-null   object
#  12  Payment                  1000 non-null   object
#  13  cogs                     1000 non-null   float64
# ...

# %%
data.isnull().sum()
# Out:
# Invoice ID                 0
# Branch                     0
# City                       0
# Customer type              0
# Gender                     0
# Product line               0
# Unit price                 0
# Quantity                   0
# Tax 5%                     0
# Total                      0
# Date                       0
# Time                       0
# Payment                    0
# cogs                       0
# gross margin percentage    0
# gross income               0
# Rating                     0
# dtype: int64

# %%
data.nunique()
# Out:
# City                         3
# Customer type                2
# Gender                       2
# Product line                 6
# Unit price                 943
# Quantity                    10
# Total                      990
# Date                        89
# Time                       506
# Payment                      3
# cogs                       990
# gross margin percentage      1
# gross income               990
# Rating                      61
# month                        3
# Year                         1
# day                         31
# hour                        11
# minute                      60
# second                       1
# dtype: int64

# %%
data.columns
# Out:
# Index(['City', 'Customer type', 'Gender', 'Product line', 'Unit price',
#        'Quantity', 'Total', 'Date', 'Time', 'Payment', 'cogs',
#        'gross margin percentage', 'gross income', 'Rating', 'month', 'Year',
#        'day', 'hour', 'minute', 'second'],
#       dtype='object')

# %%
data.City.replace({'Yangon':'Lagos', 'Naypyitaw':'Abeokuta', 'Mandalay':'Oyo'}, inplace=True)

# %%
data
# Out:
#       Invoice ID Branch      City Customer type  Gender  \
# 0    750-67-8428      A     Lagos        Member  Female
# 1    226-31-3081      C  Abeokuta        Normal  Female
# 2    631-41-3108      A     Lagos        Normal    Male
# 3    123-19-1176      A     Lagos        Member    Male
# 4    373-73-7910      A     Lagos        Normal    Male
# ..           ...    ...       ...           ...     ...
# 995  233-67-5758      C  Abeokuta        Normal    Male
# 996  303-96-2227      B       Oyo        Normal  Female
# 997  727-02-1313      A     Lagos        Member    Male
# 998  347-56-2442      A     Lagos        Normal    Male
# 999  849-09-3807      A     Lagos        Member  Female
#
#                Product line  Unit price  Quantity   Tax 5%      Total  \
# 0         Health and beauty       74.69         7  26.1415   548.9715
# 1    Electronic accessories       15.28         5   3.8200    80.2200
# 2        Home and lifestyle       46.33         7  16.2155   340.5255
# ...

# %%
data.drop(['Invoice ID','Branch','Tax 5%'], axis=1, inplace=True)

# %%
data
# Out:
#          City Customer type  Gender            Product line  Unit price  \
# 0       Lagos        Member  Female       Health and beauty       74.69
# 1    Abeokuta        Normal  Female  Electronic accessories       15.28
# 2       Lagos        Normal    Male      Home and lifestyle       46.33
# 3       Lagos        Member    Male       Health and beauty       58.22
# 4       Lagos        Normal    Male       Sports and travel       86.31
# ..        ...           ...     ...                     ...         ...
# 995  Abeokuta        Normal    Male       Health and beauty       40.35
# 996       Oyo        Normal  Female      Home and lifestyle       97.38
# 997     Lagos        Member    Male      Food and beverages       31.84
# 998     Lagos        Normal    Male      Home and lifestyle       65.82
# 999     Lagos        Member  Female     Fashion accessories       88.34
#
#      Quantity      Total       Date   Time      Payment    cogs  \
# ...

# %%
data['Product line'].value_counts()
# Out:
# Fashion accessories       178
# Food and beverages        174
# Electronic accessories    170
# Sports and travel         166
# Home and lifestyle        160
# Health and beauty         152
# Name: Product line, dtype: int64

# %%
data.City.value_counts()
# Out:
# Lagos       340
# Oyo         332
# Abeokuta    328
# Name: City, dtype: int64

# %%
data['Customer type'].value_counts()
# Out:
# Member    501
# Normal    499
# Name: Customer type, dtype: int64

# %%
import datetime as dt

# %%
data['Date']= pd.to_datetime(data.Date)

# %%
data['month']=data['Date'].dt.month
data['Year'] = data['Date'].dt.year
data['day'] = data['Date'].dt.day

# %%
data['Time']=pd.to_datetime(data.Time)

# %%
data['hour']=data['Time'].dt.hour
data['minute']=data['Time'].dt.minute
data['second']=data['Time'].dt.second

# %%
data
# Out:
#          City Customer type  Gender            Product line  Unit price  \
# 0       Lagos        Member  Female       Health and beauty       74.69
# 1    Abeokuta        Normal  Female  Electronic accessories       15.28
# 2       Lagos        Normal    Male      Home and lifestyle       46.33
# 3       Lagos        Member    Male       Health and beauty       58.22
# 4       Lagos        Normal    Male       Sports and travel       86.31
# ..        ...           ...     ...                     ...         ...
# 995  Abeokuta        Normal    Male       Health and beauty       40.35
# 996       Oyo        Normal  Female      Home and lifestyle       97.38
# 997     Lagos        Member    Male      Food and beverages       31.84
# 998     Lagos        Normal    Male      Home and lifestyle       65.82
# 999     Lagos        Member  Female     Fashion accessories       88.34
#
#      Quantity      Total       Date                Time      Payment    cogs  \
# ...

# %% [markdown]
# 1.Lagos has the highest customer

# %%
sns.countplot('City', data=data);

# %%
data.Gender.value_counts()
# Out:
# Female    501
# Male      499
# Name: Gender, dtype: int64

# %% [markdown]
# Male has the highest ount in Lagos,
# Female has the highest ount in Abeokuta,
# Male has the highest ount in Oyo

# %%
sns.countplot('City', hue='Gender', data=data)

# %%
plt.figure(figsize=(12,6))
sns.countplot('Product line', data=data)
plt.xticks(rotation=45)
# Out:
# (array([0, 1, 2, 3, 4, 5]), <a list of 6 Text major ticklabel objects>)

# %%
plt.figure(figsize=(12,8))
sns.countplot('Product line', hue='Gender',data=data)
plt.xticks(rotation=45)
# Out:
# (array([0, 1, 2, 3, 4, 5]), <a list of 6 Text major ticklabel objects>)

# %%
sns.boxplot(y='Product line', x='gross income', data=data)

# %%
plt.figure(figsize=(12,6))
sns.boxplot(x='Product line',y='Rating', data=data)

# %%
sns.barplot(y='Rating',x='Gender',data=data)

# %%
data['Customer type'].value_counts()
# Out:
# Member    501
# Normal    499
# Name: Customer type, dtype: int64

# %%
sns.countplot('Customer type', hue='City',data=data)

# %%
sns.countplot('City', hue='Customer type', data=data)

# %%
data.month.value_counts()
# Out:
# 1    352
# 3    345
# 2    303
# Name: month, dtype: int64

# %%
sns.countplot('month', data=data)

# %%
sns.boxplot(y= 'gross income', x='month', data=data)

# %%
sns.boxplot(y='Total', x='month', data=data);

# %%
data.head()
# Out:
#     Invoice ID Branch       City Customer type  Gender  \
# 0  750-67-8428      A     Yangon        Member  Female
# 1  226-31-3081      C  Naypyitaw        Normal  Female
# 2  631-41-3108      A     Yangon        Normal    Male
# 3  123-19-1176      A     Yangon        Member    Male
# 4  373-73-7910      A     Yangon        Normal    Male
#
#              Product line  Unit price  Quantity   Tax 5%     Total       Date  \
# 0       Health and beauty       74.69         7  26.1415  548.9715 2019-01-05
# 1  Electronic accessories       15.28         5   3.8200   80.2200 2019-03-08
# 2      Home and lifestyle       46.33         7  16.2155  340.5255 2019-03-03
# 3       Health and beauty       58.22         8  23.2880  489.0480 2019-01-27
# 4       Sports and travel       86.31         7  30.2085  634.3785 2019-02-08
#
#     Time      Payment    cogs  gross margin percentage  gross income  Rating  \
# 0  13:08      Ewallet  522.83                 4.761905       26.1415     9.1
# ...

# %%
gender= data.groupby('Gender')
gender.agg({'gross income':'mean'})
# Out:
#         gross income
# Gender
# Female     15.956936
# Male       14.799487

# %%
gender=data.groupby('Gender')
gender.agg({'Total':'mean'})
# Out:
#              Total
# Gender
# Female  335.095659
# Male    310.789226

# %%
gender=data.groupby('Gender')
gender.agg({'Rating':'mean'})
# Out:
#           Rating
# Gender
# Female  6.964471
# Male    6.980962

# %%
data.hour.value_counts()
# Out:
# 19    113
# 13    103
# 15    102
# 10    101
# 18     93
# 11     90
# 12     89
# 14     83
# 16     77
# 20     75
# 17     74
# Name: hour, dtype: int64

# %%
data.Quantity.value_counts()
# Out:
# 10    119
# 1     112
# 4     109
# 7     102
# 5     102
# 6      98
# 9      92
# 2      91
# 3      90
# 8      85
# Name: Quantity, dtype: int64

# %%
data.groupby('Product line')['Quantity']
# Out:
#           City Customer type  Gender            Product line  Unit price  \
# 0       Yangon        Member  Female       Health and beauty       74.69
# 1    Naypyitaw        Normal  Female  Electronic accessories       15.28
# 2       Yangon        Normal    Male      Home and lifestyle       46.33
# 3       Yangon        Member    Male       Health and beauty       58.22
# 4       Yangon        Normal    Male       Sports and travel       86.31
# ..         ...           ...     ...                     ...         ...
# 995  Naypyitaw        Normal    Male       Health and beauty       40.35
# 996   Mandalay        Normal  Female      Home and lifestyle       97.38
# 997     Yangon        Member    Male      Food and beverages       31.84
# 998     Yangon        Normal    Male      Home and lifestyle       65.82
# 999     Yangon        Member  Female     Fashion accessories       88.34
#
#      Quantity      Total       Date                Time      Payment    cogs  \
# ...

# %%
data.Payment.value_counts()
# Out:
# Ewallet        345
# Cash           344
# Credit card    311
# Name: Payment, dtype: int64

# %%
sns.countplot('Payment', hue='Gender',data=data);

# %%
sns.countplot('Payment', hue='Customer type', data=data);

# %%
City= data.groupby('City')
City.agg({'Rating':'mean'})
# Out:
#             Rating
# City
# Abeokuta  7.072866
# Lagos     7.027059
# Oyo       6.818072

# %%
sns.barplot(x='Rating', y='City', data=data)

# %%
sns.barplot(x='Rating',y='Product line', data=data)

# %% [markdown]
# Observation and Conclusions.

# %% [markdown]
# * Lagos has the highest customers.
# * Male has the highest count in Lagos, Female has the highest count in Abekuta and Male has the highest count in Oyo
# * Fashion acessories has the largest sales
# *  Healtha and beauty was bought most by male
# * Fashion acessories was bought more by female
# * Food and beverages has the highest average rating
# * Female has the highest average rating.
# *Members customer has the highest type
# * Lagos has high NORMAL customer type,Abeokuta has high MEMEBER customer type while Oyo has high NORMAL customer.
# * The first month of the year has the highest gross income.
# * The first month has the highest sales.
# * Female spend more on average
# * The 19th hour has the highest sales.
# * The min quantity purchased is at 85
# * Male use more of Ewallet while Female used more of cash payment.
# * NORMAL customer type use more of Ewallet while MEMBER use more if redit card.
